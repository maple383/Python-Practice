# %%
# IMBD評價分析 - 長條圖

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv

movie=[]
year=[]
imbd=[]
meta=[]
vote=[]

years = []
with open ('movie_ratings.csv',encoding='utf-8') as f :
    data = list(csv.reader(f))
    
    for record in data[1:]:   # data[1:] 第一筆資料
        
        movie.append(record[1])
        year.append(record[2])
        imbd.append(record[3])
        meta.append(record[4])
        vote.append(record[5])
        
        
    for i in year:   # 各年份只取一次
        if i not in years:
            years.append(i)   # ['2015', '2016', '2017', '2018']


            
sum_imbd_2015=0
sum_imbd_2016=0
sum_imbd_2017=0
sum_imbd_2018=0


sum_meta_2015=0
sum_meta_2016=0
sum_meta_2017=0
sum_meta_2018=0



sum_vote_2015=0
sum_vote_2016=0
sum_vote_2017=0
sum_vote_2018=0


# 把各個投票數、評價數，依各個年份轉化總分

for i in year:
    if i =='2015':
        
        for x in imbd:
            x = float(x)
            sum_imbd_2015+=x
            
        for x in meta :
            x=int(x)
            sum_meta_2015+=x
            
        for x in vote :
            x=int(x)
            sum_vote_2015+=x
    
    elif i=='2016':
        
        for x in imbd:
            x = float(x)
            sum_imbd_2016+=x
            
        for x in meta :
            x=int(x)
            sum_meta_2016+=x
            
        for x in vote :
            x=int(x)
            sum_vote_2016+=x
            
    elif i =='2017':
        
        for x in imbd:
            x = float(x)
            sum_imbd_2017+=x
            
        for x in meta :
            x=int(x)
            sum_meta_2017+=x
            
        for x in vote :
            x=int(x)
            sum_vote_2017+=x
            
    else:
        
        for x in imbd:
            x = float(x)
            sum_imbd_2018+=x
            
        for x in meta :
            x=int(x)
            sum_meta_2018+=x
            
        for x in vote :
            x=int(x)
            sum_vote_2018+=x

# 把所有每年的各個資料總和轉化為字串
imbds=[sum_imbd_2015,sum_imbd_2016,sum_imbd_2017,sum_imbd_2018]
metas = [sum_meta_2015,sum_meta_2016,sum_meta_2017,sum_meta_2018]
votes = [sum_vote_2015,sum_vote_2016,sum_vote_2017,sum_vote_2018]


index = np.arange(len(years))
width = 0.35

# IMBD圖表
IMBD = plt.bar(index , imbds ,width, color = "#0000CC" )

#設定圖表名稱以及 x 軸、y 軸名稱和標籤
plt.title("MOVIE_IMBD", fontsize = 18)
plt.xlabel('YEARS',size = 16)
plt.ylabel('SCORE',size = 13)

plt.xticks(index,years)   # 顯示 x軸標註
plt.yticks(np.arange(0,1000000,100000))       #  顯示 y軸標註
  
plt.show()


# META圖表
IMBD = plt.bar(index , metas ,width, color = "#AA0000" )


plt.title("MOVIE_META", fontsize = 18)
plt.xlabel('YEARS',size = 16)
plt.ylabel('SCORE',size = 13)

plt.xticks(index,years)   
plt.yticks(np.arange(0,10000000,1000000)) 

plt.show()


# VOTE投票數圖表
IMBD = plt.bar(index , votes ,width, color = "#006030" )


plt.title("MOVIE_VOTE", fontsize = 18)
plt.xlabel('YEARS',size = 16)
plt.ylabel('VOTER',size = 13)

plt.xticks(index,years)   
plt.yticks(np.arange(0,50000000000,2000000000)) 

plt.show()

# %%
# IMBD評價分析 - 圓餅圖

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv

movie=[]
year=[]
imbd=[]
meta=[]
vote=[]

years = []
with open ('movie_ratings.csv',encoding='utf-8') as f :
    data = list(csv.reader(f))
    
    for record in data[1:]:   # data[1:] 第一筆資料
        
        movie.append(record[1])
        year.append(record[2])
        imbd.append(record[3])
        meta.append(record[4])
        vote.append(record[5])
        
        
    for i in year:   # 各年份只取一次
        if i+' year' not in years:
            years.append(i+' year')   # ['2015 year', '2016 year', '2017 year', '2018 year']


            
sum_imbd_2015=0
sum_imbd_2016=0
sum_imbd_2017=0
sum_imbd_2018=0


sum_meta_2015=0
sum_meta_2016=0
sum_meta_2017=0
sum_meta_2018=0



sum_vote_2015=0
sum_vote_2016=0
sum_vote_2017=0
sum_vote_2018=0

        
y_2015=0
y_2016=0
y_2017=0
y_2018=0

# 把各個投票數、評價數，依各個年份轉化總分

for i in year:
    if i =='2015':
        y_2015+=1
        for x in imbd:
            x = float(x)
            sum_imbd_2015+=x
            
        for x in meta :
            x=int(x)
            sum_meta_2015+=x
            
        for x in vote :
            x=int(x)
            sum_vote_2015+=x
    
    elif i=='2016':
        y_2016+=1
        for x in imbd:
            x = float(x)
            sum_imbd_2016+=x
            
        for x in meta :
            x=int(x)
            sum_meta_2016+=x
            
        for x in vote :
            x=int(x)
            sum_vote_2016+=x
            
    elif i =='2017':
        y_2017+=1
        for x in imbd:
            x = float(x)
            sum_imbd_2017+=x
            
        for x in meta :
            x=int(x)
            sum_meta_2017+=x
            
        for x in vote :
            x=int(x)
            sum_vote_2017+=x
            
    else:
        y_2018+=1
        for x in imbd:
            x = float(x)
            sum_imbd_2018+=x
            
        for x in meta :
            x=int(x)
            sum_meta_2018+=x
            
        for x in vote :
            x=int(x)
            sum_vote_2018+=x

# 把所有每年的各個資料總和轉化為字串

movies = [y_2015,y_2016,y_2017,y_2018]
imbds=[sum_imbd_2015,sum_imbd_2016,sum_imbd_2017,sum_imbd_2018]
metas = [sum_meta_2015,sum_meta_2016,sum_meta_2017,sum_meta_2018]
votes = [sum_vote_2015,sum_vote_2016,sum_vote_2017,sum_vote_2018]


color = ['yellow','skyblue','lightcoral','lightgreen']

explode = [0,0.1,0,0]  

# 數據顯示格式
autopct = '%.1f%%'  

# 起始角度
startangle = 90

figl,ax1 = plt.subplots()
ax1.pie(imbds, labels = years , explode = explode , colors = color , 
        autopct = autopct , startangle = startangle)

# 圖表標題
ax1.set_title('Evaluation of the movie of the year',size = 20)
plt.show()

# %%
# Yahoo奇摩電影 - 電影名稱、日期、星等、投票數


from requests import get
from bs4 import BeautifulSoup
import pandas as pd

numbers=[]
movies =[]
times=[]
stars=[]
votes=[]

print('Yahoo奇摩電影','\n')

html = requests.get('https://movies.yahoo.com.tw/chart.html?cate=rating')
bs = BeautifulSoup(html.text,'html.parser')
datas = bs.find('div',class_='rank_list table rankstyle3')

# 數字 1 ~ 20
for i in range(1,21):
    numbers.append(i)


# 第一個電影名稱
first_movie = bs.find('dl',class_='rank_list_box').find('h2').text
movies.append(first_movie)

# 其他所有電影名稱
movie = datas.find_all('div',{'class':{'rank_txt'}})
for i in movie:
    movies.append(i.text)


for i in range(1,21):
    
    # 電影上映日期
    time = datas.find_all('div',class_='tr')[i].find_all('div',class_='td')[2].text
    times.append(time)
    
    # 電影星等
    star = datas.find_all('div',class_='tr')[i].find('h6').text
    stars.append(star)
    
    # 投票數
    vote = datas.find_all('div',class_='tr')[i].find('h4').text
    votes.append(vote)
    
    
movie_info = pd.DataFrame({'電影名稱':movies,
                             '上映日期':times,
                             '星等':stars,
                             '投票人數':votes} , index=numbers)
movie_info
# Out:
# Yahoo奇摩電影
#                      電影名稱        上映日期   星等     投票人數
# 1         我的英雄學院劇場版：英雄新世紀  2020-04-01  4.5  共229人投票
# 2            來自深淵 深沉靈魂的黎明  2020-04-10  4.5   共63人投票
# 3                   羊男的迷宮  2020-04-01  4.5   共53人投票
# 4                  我的粉紅人生  2020-04-17  4.5   共45人投票
# 5   數碼寶貝 LAST EVOLUTION 絆  2020-04-24  4.4   共28人投票
# 6        在黑暗中漫舞：20週年數位修復版  2020-04-01  4.3   共19人投票
# 7                  二階堂家物語  2020-04-24  4.3   共19人投票
# 8                      搞鬼  2020-04-10  4.2  共127人投票
# 9              知道天空有多藍的人啊  2020-04-17  4.2   共48人投票
# 10                   拾光人生  2020-04-01  4.2   共38人投票
# 11                 美好拾光公司  2020-04-24  4.2    共5人投票
# 12                    謝謝你  2020-04-10  4.2    共4人投票
# 13                     真實  2020-04-10  4.1   共37人投票
# 14                  靈異孤兒院  2020-04-24  4.1    共8人投票
# 15                  下女的誘惑  2020-04-10  4.1    共4人投票
# 16               搭火車旅行好吃驚  2020-04-24  4.1    共4人投票
# 17                  緣來想見妳  2020-04-24  4.1    共2人投票
# ...
